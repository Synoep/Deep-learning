# %% [markdown]
# # Name : Khushi Rathi
# # Roll NO :05
# # Batch B1
# # Practical :05(B)

# %% [markdown]
# # Practical 5(A)

# %%
import matplotlib.pyplot as plt
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers

# %%
def relu_func(z):
    return np.maximum(0, z)

# %%
x = np.linspace(-3, 3, 61)
y_true = np.sin(x)
# initializing the random number generator
np.random.seed(42)

# %%
# defining size of each layer
input_size = 1
hidden_size = 10
output_size = 1

# %%
# initially weights (W1 & W2) are random and bias (b1 & b2) are zero
W1 = np.random.randn(input_size, hidden_size)
b1 = np.zeros((1, hidden_size))
W2 = np.random.randn(hidden_size, output_size)
b2 = np.zeros((1, output_size))

# %%
learning_rate = 0.01
epochs = 1000

# %%
for epoch in range(epochs):
    # forward pass
    Z1 = np.dot(x.reshape(-1, 1), W1) + b1
    A1 = relu_func(Z1)
    Z2 = np.dot(A1, W2) + b2
    y_pred = Z2.flatten() # predicted y
    # calculating the loss
    loss = np.mean((y_pred - y_true)**2)

# %%
plt.plot(x, y_true, label='True sine curve')
plt.plot(x, y_pred, label='Neural network approximation')
plt.legend()
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.title('Sine function & Neural Network Approximation')
plt.show()

# %% [markdown]
# # Practical 5(B)

# %%
import matplotlib.pyplot as plt
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers

# %%
# Loding the MNIST dataset from keras.dataset
(x_train, y_train),(x_test,y_test) = keras.datasets.mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# normalizing the data
x_train = x_train/255.0
x_test = x_test/255.0

# %%
def create_model(hidden_layers=1, neurons=64, activation='relu', input_shape=(28, 28)):
  model = keras.Sequential()
  model.add(keras.layers.Flatten(input_shape=input_shape))
  for _ in range(hidden_layers):
    model.add(layers.Dense(neurons, activation=activation))
  model.add(layers.Dense(10, activation='softmax'))
  return model

# %%
model = create_model(hidden_layers=2, neurons=64, activation='relu', input_shape=(28, 28))
model.compile(optimizer='sgd', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# fitting the model on the training dataset
history = model.fit(x_train, y_train, epochs=10, validation_split=0.1)
# Out:
# Epoch 1/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.6601 - loss: 1.2036 - val_accuracy: 0.9073 - val_loss: 0.3236
# Epoch 2/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9004 - loss: 0.3546 - val_accuracy: 0.9333 - val_loss: 0.2406
# Epoch 3/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9195 - loss: 0.2823 - val_accuracy: 0.9412 - val_loss: 0.2058
# Epoch 4/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9321 - loss: 0.2369 - val_accuracy: 0.9487 - val_loss: 0.1870
# Epoch 5/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9401 - loss: 0.2121 - val_accuracy: 0.9508 - val_loss: 0.1666
# Epoch 6/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9475 - loss: 0.1879 - val_accuracy: 0.9552 - val_loss: 0.1613
# Epoch 7/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.9508 - loss: 0.1717 - val_accuracy: 0.9597 - val_loss: 0.1429
# Epoch 8/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9549 - loss: 0.1574 - val_accuracy: 0.9620 - val_loss: 0.1377
# Epoch 9/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9584 - loss: 0.1456 - val_accuracy: 0.9650 - val_loss: 0.1275
# Epoch 10/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9602 - loss: 0.1358 - val_accuracy: 0.9660 - val_loss: 0.1220

# %%
# model evaluation
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9511 - loss: 0.1651
# Test Accuracy: 0.9581

# %%
model2 = create_model(hidden_layers=2, neurons=64, activation='sigmoid', input_shape=(28, 28))
model2.compile(optimizer='sgd', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# fitting the model on the training dataset
history2 = model2.fit(x_train, y_train, epochs=10, validation_split=0.1)
# Out:
# Epoch 1/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.1740 - loss: 2.2786 - val_accuracy: 0.4870 - val_loss: 2.1514
# Epoch 2/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.5097 - loss: 2.0732 - val_accuracy: 0.6365 - val_loss: 1.7043
# Epoch 3/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.6438 - loss: 1.5741 - val_accuracy: 0.7592 - val_loss: 1.1349
# Epoch 4/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7375 - loss: 1.0879 - val_accuracy: 0.8300 - val_loss: 0.8192
# Epoch 5/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7937 - loss: 0.8318 - val_accuracy: 0.8525 - val_loss: 0.6428
# Epoch 6/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8237 - loss: 0.6770 - val_accuracy: 0.8755 - val_loss: 0.5354
# Epoch 7/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8466 - loss: 0.5851 - val_accuracy: 0.8880 - val_loss: 0.4652
# Epoch 8/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8617 - loss: 0.5204 - val_accuracy: 0.8957 - val_loss: 0.4177
# Epoch 9/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8703 - loss: 0.4795 - val_accuracy: 0.9018 - val_loss: 0.3838
# Epoch 10/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8789 - loss: 0.4449 - val_accuracy: 0.9095 - val_loss: 0.3583

# %%
# model evaluation
test_loss2, test_accuracy2 = model2.evaluate(x_test, y_test)
print(f"Test Accuracy: {test_accuracy2:.4f}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8743 - loss: 0.4513
# Test Accuracy: 0.8907

# %%
model3 = create_model(hidden_layers=2, neurons=64, activation='tanh', input_shape=(28, 28))
model3.compile(optimizer='sgd', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# fitting the model on the training dataset
history3 = model3.fit(x_train, y_train, epochs=10, validation_split=0.1)
# Out:
# Epoch 1/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7347 - loss: 1.0447 - val_accuracy: 0.9180 - val_loss: 0.3284
# Epoch 2/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8996 - loss: 0.3665 - val_accuracy: 0.9292 - val_loss: 0.2578
# Epoch 3/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9144 - loss: 0.3023 - val_accuracy: 0.9383 - val_loss: 0.2273
# Epoch 4/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9242 - loss: 0.2667 - val_accuracy: 0.9452 - val_loss: 0.2043
# Epoch 5/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9298 - loss: 0.2436 - val_accuracy: 0.9480 - val_loss: 0.1901
# Epoch 6/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9356 - loss: 0.2245 - val_accuracy: 0.9552 - val_loss: 0.1748
# Epoch 7/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9409 - loss: 0.2049 - val_accuracy: 0.9585 - val_loss: 0.1628
# Epoch 8/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9470 - loss: 0.1873 - val_accuracy: 0.9603 - val_loss: 0.1518
# Epoch 9/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9492 - loss: 0.1759 - val_accuracy: 0.9627 - val_loss: 0.1433
# Epoch 10/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9520 - loss: 0.1678 - val_accuracy: 0.9628 - val_loss: 0.1372

# %%
# model evaluation
test_loss3, test_accuracy3 = model3.evaluate(x_test, y_test)
print(f"Test Accuracy: {test_accuracy3:.4f}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9448 - loss: 0.1807
# Test Accuracy: 0.9529

# %%
activations = ['relu', 'sigmoid', 'tanh']
test_accuracies = [test_accuracy, test_accuracy2, test_accuracy3]
plt.figure(figsize=(8, 6))
plt.bar(activations, test_accuracies, color=['skyblue', 'lightcoral', 'lightgreen'])
plt.xlabel("Activation Function")
plt.ylabel("Test Accuracy")
plt.title("Test Accuracy for Different Activation Functions")
plt.ylim(0, 1)
plt.show()

# %% [markdown]
# # Practical 5 (c)

# %%
(x_train, y_train),(x_test,y_test) = keras.datasets.fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 1us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
x_train = x_train/255.0
x_test = x_test/255.0

# %%
def create_model(hidden_layers=1, neurons=64, activation='relu', input_shape=(28, 28)):
  model = keras.Sequential()
  model.add(keras.layers.Flatten(input_shape=input_shape))
  for _ in range(hidden_layers):
    model.add(layers.Dense(neurons, activation=activation))
  model.add(layers.Dense(10, activation='softmax'))
  return model

# %%
model = create_model(hidden_layers=2, neurons=64, activation='relu', input_shape=(28, 28))
model.compile(optimizer='sgd', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
history = model.fit(x_train, y_train, epochs=10, validation_split=0.1)
# Out:
# Epoch 1/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.6471 - loss: 1.1079 - val_accuracy: 0.7983 - val_loss: 0.5618
# Epoch 2/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8161 - loss: 0.5323 - val_accuracy: 0.8293 - val_loss: 0.4959
# Epoch 3/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8319 - loss: 0.4802 - val_accuracy: 0.8405 - val_loss: 0.4538
# Epoch 4/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8472 - loss: 0.4437 - val_accuracy: 0.8487 - val_loss: 0.4267
# Epoch 5/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8515 - loss: 0.4241 - val_accuracy: 0.8485 - val_loss: 0.4260
# Epoch 6/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8584 - loss: 0.4057 - val_accuracy: 0.8542 - val_loss: 0.4199
# Epoch 7/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8630 - loss: 0.3913 - val_accuracy: 0.8563 - val_loss: 0.3967
# Epoch 8/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8637 - loss: 0.3855 - val_accuracy: 0.8592 - val_loss: 0.3920
# Epoch 9/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8710 - loss: 0.3656 - val_accuracy: 0.8558 - val_loss: 0.3964
# Epoch 10/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8734 - loss: 0.3569 - val_accuracy: 0.8617 - val_loss: 0.3940

# %%
test_loss3, test_accuracy3 = model3.evaluate(x_test, y_test)
print(f"Test Accuracy: {test_accuracy3:.4f}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1116 - loss: 5.9292
# Test Accuracy: 0.1119

# %%
activations = ['relu', 'sigmoid', 'tanh']
test_accuracies = [test_accuracy, test_accuracy2, test_accuracy3]
plt.figure(figsize=(8, 6))
plt.bar(activations, test_accuracies, color=['skyblue', 'lightcoral', 'lightgreen'])
plt.xlabel("Activation Function")
plt.ylabel("Test Accuracy")
plt.title("Test Accuracy for Different Activation Functions")
plt.ylim(0, 1)
plt.show()
